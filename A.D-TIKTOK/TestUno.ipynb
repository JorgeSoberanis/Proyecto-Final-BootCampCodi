# %%
import pandas as pd
import numpy as np
import altair as alt
from vega_datasets import data

# %% [markdown]
# # Aqui lo que se hace es leer el archivo .csv y se imprimen los primeros cinco c:

# %%
dt = pd.read_csv("tiktok.csv", index_col= "id")
dt
# Out:
#                    track_id                       track_name  \
# id
# 0    6kVuF2PYLuvl9T85XjNbaO          Lay It Down Gmix - Main
# 1    1RGIjMFMgJxkZHMDXVYzOJ           Bartender (feat. Akon)
# 2    1RGIjMFMgJxkZHMDXVYzOJ           Bartender (feat. Akon)
# 3    1dIWPXMX4kRHj6Dt2DStUQ     Chosen (feat. Ty Dolla $ign)
# 4    4QVS8YCpK71R4FsxSMCjhP    Tie Me Down (with Elley Duhé)
# ..                      ...                              ...
# 994  0XHyNndHIiLADEPrUHpia8          Shining (feat. 42 Dugg)
# 995  5NFr84NNaAHt5B4zK9Vouh                         Catch Me
# 996  3AoT7FzXEsmesybPPIQd9l                    Buck the Jack
# 997  2NtcRpiK7HnSA8CuBQyY16  Whatchu On Today (feat. Polo G)
# 998  0jrHAEavOcFSLUgxxG5e37                          Hold On
#
#                   artist_id       artist_name                album_id  \
# id
# 0    1Xfmvd48oOhEWkscWyEbh9             Lloyd  43C6GVlhXG4KfZuEbxty3r
# 1    3aQeKQSyrW4qWr35idm0cy            T-Pain  6CrSEKCF4TYrbSIitegb3h
# ...

# %% [markdown]
# ### Quiero eliminar unas columnas para que el datasets quede mas facil de leer, vamos a ver que tal

# %%
data = dt.drop(['track_id', "artist_id","album_id", "duration", "danceability", "energy", "key", "speechiness", "acousticness", "instrumentalness", "liveness", "playlist_name", "playlist_id"], axis=1)

# %% [markdown]
# ## Primer grafico de barras que muestre los artistas del dataframe con Altair c:

# %%
alt.Chart(data).mark_bar().encode(
    x= alt.X("popularity",title = "Popularidad"),
    y= alt.Y("artist_name:O", title= "Artista"),
    color= alt.condition(
        alt.datum.popularity >= 70,
        alt.value("orange"),
        alt.value("steelblue")
    )

).properties(
    title = f"Popularidad de los artistas en TikTok. Diciembre 2021",
    width = 600,
)
# Out:
# alt.Chart(...)
